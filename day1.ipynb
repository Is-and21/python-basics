# %%
#basic mathemaical operation
#addition
a=10;
b=20;
print(a+b)
# Out:
# 30

# %%
#sub
a=10
b=5
print(a-b)
# Out:
# 5

# %%
#mul & div
a=6
b=2
print(a*b)
print(a/b)
# Out:
# 12
# 3.0

# %%
# swappping of variables
a=10
b=5
a,b=b,a
print(a,b)
# Out:
# 5 10

# %%
#conversions:
#even_odd
n= int(input())
if n%2==0:
    print("even")
else:
    print("odd")
# Out:
#  20
# even

# %%
#conversions:
#celsius to fahrenheit
c=float(input("enter temp in celsius()"))
f= (9*c)/5 + 32
print(f)
# Out:
# enter temp in celsius() 50
# 122.0

# %%
#simple interest
#i=ptr/100
p= int(input("enter principle amount "))
t=float(input("time in years "))
r= float(input("rate of interest "))
i = (p*t*r )/ 100
print("the interest is", i)
print("the total amount is ", p+i)
# Out:
# enter principle amount  900000
# time in years  1
# rate of interest  24
# the interest is 216000.0
# the total amount is  1116000.0

# %%
#area of rectngle
l= int(input(" length "))
b= int(input(" breadth "))
print( " the area is: ", l*b)
# Out:
#  length  10
#  breadth  111
#  the area is:  1110

# %%
#square root of a number
n= int( input( " enter num: "))
sqrt_num = n ** 0.5
print("square root ", float(sqrt_num))
# Out:
#  enter num:  25
# square root  5.0
